# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent = [ 'the glass of milk',
        'the glass of juice',
        'the cup of tea',
        'I am a good boy',
        'I am a good developer',
        'understand the meaning of words',
        'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
voc_size = 10000

# %%
one_hot_rep = [one_hot(word,voc_size) for word in sent]
one_hot_rep
# Out:
# [[2403, 8201, 1853, 6309],
#  [2403, 8201, 1853, 5542],
#  [2403, 2930, 1853, 7006],
#  [899, 1275, 3363, 4164, 3978],
#  [899, 1275, 3363, 4164, 1763],
#  [5474, 2403, 9514, 1853, 7317],
#  [7527, 5798, 2190, 4164]]

# %%
## word embedding representation

from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
sent_length = 8

embbed_docs = pad_sequences(one_hot_rep,padding="pre",maxlen=sent_length)
print(embbed_docs)
# Out:
# [[   0    0    0    0 2403 8201 1853 6309]
#  [   0    0    0    0 2403 8201 1853 5542]
#  [   0    0    0    0 2403 2930 1853 7006]
#  [   0    0    0  899 1275 3363 4164 3978]
#  [   0    0    0  899 1275 3363 4164 1763]
#  [   0    0    0 5474 2403 9514 1853 7317]
#  [   0    0    0    0 7527 5798 2190 4164]]

# %%
## feature representation 
dim =10

# %%
model = Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile("adam","mse")
# Out:
# c:\Users\vipin\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.predict(embbed_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# array([[[-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.00178923,  0.00257152,  0.00951462, -0.02304392,
#          -0.02407538, -0.03857619,  0.0143081 ,  0.03425748,
#           0.00427506, -0.01582999],
#         [-0.03472745, -0.03919066,  0.0339708 ,  0.03980294,
#          -0.03333252, -0.0482146 ,  0.03175334, -0.00714618,
#           0.00689129,  0.01436719],
#         [-0.00758109, -0.03590208,  0.03216257, -0.04957149,
#          -0.03792527,  0.01195697, -0.01469463,  0.01083767,
#          -0.02379327, -0.0157724 ],
#         [ 0.02675052, -0.02623597,  0.01574227,  0.03730908,
#          -0.04789827,  0.04545652, -0.01175141,  0.01133473,
#           0.01694988, -0.00796702]],
#
#        [[-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.00178923,  0.00257152,  0.00951462, -0.02304392,
#          -0.02407538, -0.03857619,  0.0143081 ,  0.03425748,
#           0.00427506, -0.01582999],
#         [-0.03472745, -0.03919066,  0.0339708 ,  0.03980294,
#          -0.03333252, -0.0482146 ,  0.03175334, -0.00714618,
#           0.00689129,  0.01436719],
#         [-0.00758109, -0.03590208,  0.03216257, -0.04957149,
#          -0.03792527,  0.01195697, -0.01469463,  0.01083767,
#          -0.02379327, -0.0157724 ],
#         [ 0.03998419,  0.01448511,  0.00248045,  0.00086684,
#          -0.01075723, -0.044509  , -0.03336691,  0.02454001,
#           0.03869383,  0.0262312 ]],
#
#        [[-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.00178923,  0.00257152,  0.00951462, -0.02304392,
#          -0.02407538, -0.03857619,  0.0143081 ,  0.03425748,
#           0.00427506, -0.01582999],
#         [-0.01678426, -0.04212757,  0.01825248,  0.00326555,
#          -0.00938989, -0.00774543, -0.01394516, -0.01809342,
#          -0.04924721, -0.01250682],
#         [-0.00758109, -0.03590208,  0.03216257, -0.04957149,
#          -0.03792527,  0.01195697, -0.01469463,  0.01083767,
#          -0.02379327, -0.0157724 ],
#         [ 0.01561599,  0.01755519,  0.03441701, -0.03537745,
#           0.00613486,  0.01261598,  0.03419018,  0.03353124,
#          -0.0155897 , -0.00680356]],
#
#        [[-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.04628987,  0.00997596, -0.03596007, -0.03722791,
#          -0.00219215, -0.03157815, -0.01012913, -0.03948916,
#          -0.02580012,  0.00375211],
#         [-0.00426798,  0.02508824, -0.02497199, -0.04201793,
#           0.02388379,  0.01472018, -0.03694923,  0.01364586,
#          -0.0424206 ,  0.03417334],
#         [ 0.00723804,  0.03095508,  0.04219813,  0.02674164,
#           0.0354406 , -0.04689955,  0.04499959,  0.00265098,
#          -0.01234255, -0.02909767],
#         [-0.01206596, -0.02629896,  0.03594067,  0.02973287,
#          -0.04776449,  0.01295729,  0.00533557, -0.02073518,
#           0.02721455, -0.02992089],
#         [-0.000331  , -0.03993694,  0.02880174, -0.03137912,
#          -0.0380451 , -0.01291201,  0.00818463,  0.03433135,
#           0.03129966,  0.04021006]],
#
#        [[-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.04628987,  0.00997596, -0.03596007, -0.03722791,
#          -0.00219215, -0.03157815, -0.01012913, -0.03948916,
#          -0.02580012,  0.00375211],
#         [-0.00426798,  0.02508824, -0.02497199, -0.04201793,
#           0.02388379,  0.01472018, -0.03694923,  0.01364586,
#          -0.0424206 ,  0.03417334],
#         [ 0.00723804,  0.03095508,  0.04219813,  0.02674164,
#           0.0354406 , -0.04689955,  0.04499959,  0.00265098,
#          -0.01234255, -0.02909767],
#         [-0.01206596, -0.02629896,  0.03594067,  0.02973287,
#          -0.04776449,  0.01295729,  0.00533557, -0.02073518,
#           0.02721455, -0.02992089],
#         [-0.00974626, -0.04508162, -0.00187646,  0.04361251,
#          -0.0430019 ,  0.01971707,  0.02479341, -0.04226602,
#           0.00340126,  0.00496919]],
#
#        [[-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [ 0.04624249,  0.04879722, -0.0236861 , -0.02009409,
#           0.03071101,  0.04098263,  0.04906565, -0.00040678,
#           0.04909663,  0.02098885],
#         [-0.00178923,  0.00257152,  0.00951462, -0.02304392,
#          -0.02407538, -0.03857619,  0.0143081 ,  0.03425748,
#           0.00427506, -0.01582999],
#         [ 0.04414293,  0.04728628, -0.00387843, -0.01807457,
#           0.01770439, -0.02173326,  0.04547461,  0.04138001,
#          -0.00954422,  0.02574149],
#         [-0.00758109, -0.03590208,  0.03216257, -0.04957149,
#          -0.03792527,  0.01195697, -0.01469463,  0.01083767,
#          -0.02379327, -0.0157724 ],
#         [ 0.04297069,  0.01162145,  0.02027542, -0.04151822,
#           0.0364461 , -0.02424528,  0.04596765,  0.03152328,
#          -0.01722469, -0.01152691]],
#
#        [[-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03991815, -0.04656558, -0.0179062 , -0.02622554,
#          -0.04187808,  0.02618483, -0.01495763, -0.03977975,
#          -0.00957543,  0.01849364],
#         [-0.04597011, -0.01402702, -0.0350737 ,  0.03059999,
#          -0.01711684,  0.01995787,  0.03806484, -0.01836274,
#          -0.04739143, -0.01216267],
#         [-0.0459937 , -0.04615853, -0.02525901, -0.04752228,
#          -0.00201683, -0.04117215, -0.0226827 , -0.03855034,
#           0.04092268,  0.03850475],
#         [-0.01206596, -0.02629896,  0.03594067,  0.02973287,
#          -0.04776449,  0.01295729,  0.00533557, -0.02073518,
#           0.02721455, -0.02992089]]], dtype=float32)

# %%
embbed_docs[0]
# Out:
# array([   0,    0,    0,    0, 2403, 8201, 1853, 6309], dtype=int32)

# %%
model.predict(embbed_docs[[0]])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# array([[[-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.03923566, -0.0029569 ,  0.03843937, -0.04011004,
#           0.03514251, -0.02476605,  0.04451707,  0.03461827,
#           0.01735116,  0.02887015],
#         [-0.00178923,  0.00257152,  0.00951462, -0.02304392,
#          -0.02407538, -0.03857619,  0.0143081 ,  0.03425748,
#           0.00427506, -0.01582999],
#         [-0.03472745, -0.03919066,  0.0339708 ,  0.03980294,
#          -0.03333252, -0.0482146 ,  0.03175334, -0.00714618,
#           0.00689129,  0.01436719],
#         [-0.00758109, -0.03590208,  0.03216257, -0.04957149,
#          -0.03792527,  0.01195697, -0.01469463,  0.01083767,
#          -0.02379327, -0.0157724 ],
#         [ 0.02675052, -0.02623597,  0.01574227,  0.03730908,
#          -0.04789827,  0.04545652, -0.01175141,  0.01133473,
#           0.01694988, -0.00796702]]], dtype=float32)
